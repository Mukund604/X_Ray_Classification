# %% [markdown]
# # 98% Accuracy - Binary Classification of Bone Fracture X-rays (Fractured/Not Fractured) - CNN
# ![](https://www.mdpi.com/sensors/sensors-22-01285/article_deploy/html/images/sensors-22-01285-g020b.png)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import cv2
import warnings

warnings.filterwarnings('ignore')



base_dir = '/kaggle/input/fracture-multi-region-x-ray-data/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classification'
sub_dir = os.listdir(base_dir)
Categories = os.listdir(os.path.join(base_dir,"test"))


img_size = 100

Train_path = '/kaggle/input/fracture-multi-region-x-ray-data/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classification/train'
Test_path = '/kaggle/input/fracture-multi-region-x-ray-data/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classification/test'
Val_path = '/kaggle/input/fracture-multi-region-x-ray-data/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classification/val'




def fetch_data(path):
    data = []
    category = os.listdir(path)
    for cat in category:
        label = Categories.index(cat)
        img_dir = os.path.join(path,cat)
        images = os.listdir(img_dir)
        for img in images:
            try:
                img_array = cv2.imread(os.path.join(img_dir,img), cv2.IMREAD_GRAYSCALE)
                resized_img_array = cv2.resize(img_array, (img_size, img_size))
                data.append([resized_img_array,label])
            except Exception as e:
                pass
    return data
        

Training_data = fetch_data(Train_path)
Testing_data = fetch_data(Test_path)
Val_data = fetch_data(Val_path)
print("Training Data: ", len(Training_data), "Testing Data: ", len(Testing_data), "Validation Data: ", len(Val_data))
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# libpng warning: bKGD: invalid
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: bKGD: invalid
# libpng warning: bKGD: invalid
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# Training Data:  9243 Testing Data:  506 Validation Data:  829

# %%
import random

random.shuffle(Training_data)

def makeX_y(data):
    makeX = []
    makeY = []
    
    for X, y in data:
        makeX.append(X)
        makeY.append(y)
        
    makeX = np.array(makeX).reshape(-1, img_size,img_size, 1)
    makeX = makeX / 255.0
    makeY = np.array(makeY)
    
    return makeX, makeY


X_train, y_train = makeX_y(Training_data)
X_test, y_test = makeX_y(Testing_data)
X_val, y_val = makeX_y(Val_data)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (9243, 100, 100, 1) (9243,)
# (506, 100, 100, 1) (506,)
# (829, 100, 100, 1) (829,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout

Model = Sequential()



Model.add(Conv2D(64, (3,3), padding = 'same',input_shape=X_train.shape[1:] ))
Model.add(Activation('relu'))
Model.add(MaxPooling2D(pool_size = (2,2)))
Model.add(Dropout(0.2))

Model.add(Flatten())


Model.add(Dense(1))
Model.add(Activation('sigmoid'))

Model.summary()

Model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

History = Model.fit(X_train, y_train, epochs = 15, batch_size = 32, validation_split=0.2)
# Out:
# 2024-06-13 05:39:29.893568: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 05:39:29.893694: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 05:39:30.010340: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 100, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 100, 100, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 50, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 160000)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │       160,001 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,641 (627.50 KB)
#  Trainable params: 160,641 (627.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
#  33/232 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6173 - loss: 0.6493
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718257185.200128     105 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.7327 - loss: 0.5166 - val_accuracy: 0.8280 - val_loss: 0.3695
# Epoch 2/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9254 - loss: 0.2405 - val_accuracy: 0.9470 - val_loss: 0.1992
# Epoch 3/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9644 - loss: 0.1400 - val_accuracy: 0.9540 - val_loss: 0.1607
# Epoch 4/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9765 - loss: 0.1012 - val_accuracy: 0.9724 - val_loss: 0.1131
# Epoch 5/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9835 - loss: 0.0797 - val_accuracy: 0.9735 - val_loss: 0.1027
# Epoch 6/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9911 - loss: 0.0499 - val_accuracy: 0.9740 - val_loss: 0.0889
# Epoch 7/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9915 - loss: 0.0408 - val_accuracy: 0.9746 - val_loss: 0.0826
# Epoch 8/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9924 - loss: 0.0420 - val_accuracy: 0.9773 - val_loss: 0.0796
# Epoch 9/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9974 - loss: 0.0228 - val_accuracy: 0.9843 - val_loss: 0.0693
# Epoch 10/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9977 - loss: 0.0168 - val_accuracy: 0.9849 - val_loss: 0.0680
# Epoch 11/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9992 - loss: 0.0110 - val_accuracy: 0.9854 - val_loss: 0.0664
# Epoch 12/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9986 - loss: 0.0114 - val_accuracy: 0.9757 - val_loss: 0.0976
# Epoch 13/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9972 - loss: 0.0176 - val_accuracy: 0.9843 - val_loss: 0.0861
# Epoch 14/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9989 - loss: 0.0121 - val_accuracy: 0.9854 - val_loss: 0.0684
# Epoch 15/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9993 - loss: 0.0049 - val_accuracy: 0.9832 - val_loss: 0.0688

# %%
import matplotlib.pyplot as plt

acc = History.history['accuracy']
val_acc = History.history['val_accuracy']

loss = History.history['loss']
val_loss = History.history['val_loss']


epochs = range(1, len(acc) + 1)

plt.figure(figsize=(8,4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel("Accuracy")
plt.title("Training VS Validation - Accuracy")
plt.legend()


plt.subplot(1,2, 2)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Losss')
plt.xlabel("Epochs")
plt.ylabel('Loss')
plt.title("Training VS Validation - Loss")
plt.legend()
plt.show()

# %%
Validation_loss, Validation_accuracy = Model.evaluate(X_val, y_val)
print("Validation Loss - ", Validation_loss, "Validation Accuracy - ", Validation_accuracy)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9676 - loss: 0.1705
# Validation Loss -  0.27951759099960327 Validation Accuracy -  0.9541616439819336

# %%
y_pred = Model.predict(X_test)


threshold = 0.5
y_pred_label = []
fractured_count = 0
not_fractured_count = 0

for pred in y_pred:
    if(pred < 0.5):
        y_pred_label.append(0)
        not_fractured_count += 0
    else:
        y_pred_label.append(1)
        fractured_count += 1
        
true_count = 0
for true, pred in zip(y_test, y_pred_label):
    if true == pred:
        true_count += 1
print(f"Out of {len(y_test)} Samples, {true_count} Samples have the correct prediction from the model")
print("Accuracy ----> ", (true_count/len(y_test))*100)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Out of 506 Samples, 488 Samples have the correct prediction from the model
# Accuracy ---->  96.44268774703558
